# %%
#%matplotlib widget
# %pylab inline
pylab.rcParams['figure.figsize'] = (8, 6)
import  general.utils as utils
import  datatool.testdata as testdata
import result_analyse.visualisation as vs
#dataset,real_events,pred_events=utils.loadState('r1')
dataset,a,b=testdata.load()
real_events=dataset.activity_events
pred_events=a
#pred_events=b


vs.my_result_analyse(dataset,real_events,pred_events)
vs.my_result_analyse(dataset,real_events,b)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# visualizing real and pred
# null ========
#            existance  length  overlap_rate  positional  cardinality
# tp                 0       0             0           0            0
# fp                 0       0             0           0            0
# fn                 0       0             0           0            0
# recall             0       0             0           0            0
# precision          0       0             0           0            0
# f1                 0       0             0           0            0
# Act ========
#            existance      length  overlap_rate  positional  cardinality
# tp          8.000000  374.000000      5.835143    6.038725     6.000000
# fp          8.000000  113.000000      9.210471    9.063897     2.000000
# fn          3.000000  107.000000      5.164857    3.897378    14.000000
# recall      0.727273    0.777547      0.530468    0.607756     0.300000
# precision   0.500000    0.767967      0.387830    0.399846     0.750000
# f1          0.592593    0.772727      0.448071    0.482351     0.428571
# null ==================================
# Act ==================================
# Detailed segment results (length or frame count):
# 	true positive segments:		6.233333330601454
# 	true negative segments:		4.566666677594185
# 	insertion segments:			0.8999999910593033
# 	deletion segments:			0.4166666679084301
# 	fragmenting segments:		0.7333333343267441
# 	merge segments:				0.11666666716337204
# 	start overfill segments:	0.11666666716337204
# 	end overfill segments:		0.7499999962747097
# 	start underfill segments:	0.6166666708886623
# 	end underfill segments:		0.01666666567325592
# Detailed segment results (length or frame count):
# 	true positive segments:		0.4308755757888512
# 	true negative segments:		0.31566820347698216
# 	insertion segments:			0.06221198094025571
# 	deletion segments:			0.028801843399852946
# 	fragmenting segments:		0.05069124430133845
# 	merge segments:				0.008064516162259167
# 	start overfill segments:	0.008064516162259167
# 	end overfill segments:		0.05184331770772163
# 	start underfill segments:	0.042626728396587835
# 	end underfill segments:		0.001152073663891725
# 2SET metrics:
# 	true positive rate:			0.778
# 	deletion rate:				0.052
# 	fragmenting rate:			0.091
# 	start underfill rate:		0.077
# 	end underfill rate:			0.002
#
# 	1 - false positive rate:	0.708
# 	insertion rate:				0.140
# 	merge rate:					0.018
# 	start overfill rate:		0.018
# 	end overfill rate:			0.116
#
# Absolute values:
# ----------------
# [6.233333330601454, 4.566666677594185, 0.8999999910593033, 0.4166666679084301, 0.7333333343267441, 0.11666666716337204, 0.11666666716337204, 0.7499999962747097, 0.6166666708886623, 0.01666666567325592]
# [6.233333330601454, 4.566666677594185, 0.8999999910593033, 0.4166666679084301, 0.7333333343267441, 0.11666666716337204, 0.11666666716337204, 0.7499999962747097, 0.6166666708886623, 0.01666666567325592]
# (6.233333330601454;4.566666677594185;0.8999999910593033;0.4166666679084301;0.7333333343267441;0.11666666716337204;0.11666666716337204;0.7499999962747097;0.6166666708886623;0.01666666567325592)
#
# Normed values:
# --------------
# [0.4308755757888512, 0.31566820347698216, 0.06221198094025571, 0.028801843399852946, 0.05069124430133845, 0.008064516162259167, 0.008064516162259167, 0.05184331770772163, 0.042626728396587835, 0.001152073663891725]
# [0.4308755757888512, 0.31566820347698216, 0.06221198094025571, 0.028801843399852946, 0.05069124430133845, 0.008064516162259167, 0.008064516162259167, 0.05184331770772163, 0.042626728396587835, 0.001152073663891725]
# (0.4308755757888512;0.31566820347698216;0.06221198094025571;0.028801843399852946;0.05069124430133845;0.008064516162259167;0.008064516162259167;0.05184331770772163;0.042626728396587835;0.001152073663891725)
#
# 2SET metrics:
# -------------
# [0.777546776941034, 0.0519750521122379, 0.09147609156883689, 0.07692307742351573, 0.002079001954375427, 0.7080103376932858, 0.13953488235089379, 0.01808785537625559, 0.01808785537625559, 0.1162790692033092]
# [0.777546776941034, 0.0519750521122379, 0.09147609156883689, 0.07692307742351573, 0.002079001954375427, 0.7080103376932858, 0.13953488235089379, 0.01808785537625559, 0.01808785537625559, 0.1162790692033092]
# (0.777546776941034;0.0519750521122379;0.09147609156883689;0.07692307742351573;0.002079001954375427;0.7080103376932858;0.13953488235089379;0.01808785537625559;0.01808785537625559;0.1162790692033092)
# Standard event results:
# 	precision:	0.6363636363636364	Weighted by length:	0.8891170440258918
# 	recall:		0.7272727272727273	Weighted by length:	0.9480249478877621
# Detailed event results:
# 	Actual events:
# 		deletions:			3	27.27% of actual events
# 		merged:				1	9.09% of actual events
# 		fragmented:			3	27.27% of actual events
# 		frag. and merged:	1	9.09% of actual events
# 		correct:			3	27.27% of actual events
# 	Detected events:
# 		insertions:			8	36.36% of detected events
# 		merging:			0	0.00% of detected events
# 		fragmenting:		10	45.45% of detected events
# 		frag. and merging:	1	4.55% of detected events
# 		correct:			3	13.64% of detected events
# [0.6363636363636364, 0.7272727272727273, 0.8891170440258918, 0.9480249478877621]
# [0.6363636363636364, 0.7272727272727273, 0.8891170440258918, 0.9480249478877621]
# (0.6363636363636364;0.7272727272727273;0.8891170440258918;0.9480249478877621)
#
# [3, 3, 1, 3, 1, 10, 0, 1, 8, 11, 22]
# [3, 3, 1, 3, 1, 10, 0, 1, 8, 11, 22]
# (3;3;1;3;1;10;0;1;8;11;22)
# visualizing real and pred
# null ========
#            existance  length  overlap_rate  positional  cardinality
# tp                 0       0             0           0            0
# fp                 0       0             0           0            0
# fn                 0       0             0           0            0
# recall             0       0             0           0            0
# precision          0       0             0           0            0
# f1                 0       0             0           0            0
# Act ========
#            existance      length  overlap_rate  positional  cardinality
# tp          8.000000  406.000000      6.674211    5.885801    10.000000
# fp          0.000000   44.000000      0.834596    1.029160     4.000000
# fn          3.000000   75.000000      4.325789    4.085040     0.000000
# recall      0.727273    0.844075      0.606746    0.590301     1.000000
# precision   1.000000    0.902222      0.888851    0.851169     0.714286
# f1          0.842105    0.872180      0.721193    0.697130     0.833333
# null ==================================
# Act ==================================
# Detailed segment results (length or frame count):
# 	true positive segments:		6.766666669398546
# 	true negative segments:		5.683333333581686
# 	insertion segments:			0
# 	deletion segments:			0.4166666679084301
# 	fragmenting segments:		0
# 	merge segments:				0.36666666716337204
# 	start overfill segments:	0.19999999552965164
# 	end overfill segments:		0.1666666679084301
# 	start underfill segments:	0.38333332911133766
# 	end underfill segments:		0.45000000298023224
# Detailed segment results (length or frame count):
# 	true positive segments:		0.4688221710819016
# 	true negative segments:		0.39376443419057
# 	insertion segments:			0.0
# 	deletion segments:			0.028868360362673942
# 	fragmenting segments:		0.0
# 	merge segments:				0.025404157077856548
# 	start overfill segments:	0.013856812623063066
# 	end overfill segments:		0.011547344196690228
# 	start underfill segments:	0.02655889116199134
# 	end underfill segments:		0.03117782930525329
# 2SET metrics:
# 	true positive rate:			0.844
# 	deletion rate:				0.052
# 	fragmenting rate:			0.000
# 	start underfill rate:		0.048
# 	end underfill rate:			0.056
#
# 	1 - false positive rate:	0.886
# 	insertion rate:				0.000
# 	merge rate:					0.057
# 	start overfill rate:		0.031
# 	end overfill rate:			0.026
#
# Absolute values:
# ----------------
# [6.766666669398546, 5.683333333581686, 0, 0.4166666679084301, 0, 0.36666666716337204, 0.19999999552965164, 0.1666666679084301, 0.38333332911133766, 0.45000000298023224]
# [6.766666669398546, 5.683333333581686, 0, 0.4166666679084301, 0, 0.36666666716337204, 0.19999999552965164, 0.1666666679084301, 0.38333332911133766, 0.45000000298023224]
# (6.766666669398546;5.683333333581686;0;0.4166666679084301;0;0.36666666716337204;0.19999999552965164;0.1666666679084301;0.38333332911133766;0.45000000298023224)
#
# Normed values:
# --------------
# [0.4688221710819016, 0.39376443419057, 0.0, 0.028868360362673942, 0.0, 0.025404157077856548, 0.013856812623063066, 0.011547344196690228, 0.02655889116199134, 0.03117782930525329]
# [0.4688221710819016, 0.39376443419057, 0.0, 0.028868360362673942, 0.0, 0.025404157077856548, 0.013856812623063066, 0.011547344196690228, 0.02655889116199134, 0.03117782930525329]
# (0.4688221710819016;0.39376443419057;0.0;0.028868360362673942;0.0;0.025404157077856548;0.013856812623063066;0.011547344196690228;0.02655889116199134;0.03117782930525329)
#
# 2SET metrics:
# -------------
# [0.8440748441279795, 0.0519750521122379, 0.0, 0.047817047274100695, 0.05613305648568193, 0.8857142860957997, 0.0, 0.05714285724238252, 0.031168830484217185, 0.025974026177600616]
# [0.8440748441279795, 0.0519750521122379, 0.0, 0.047817047274100695, 0.05613305648568193, 0.8857142860957997, 0.0, 0.05714285724238252, 0.031168830484217185, 0.025974026177600616]
# (0.8440748441279795;0.0519750521122379;0.0;0.047817047274100695;0.05613305648568193;0.8857142860957997;0.0;0.05714285724238252;0.031168830484217185;0.025974026177600616)
# Standard event results:
# 	precision:	1.0	Weighted by length:	1.0
# 	recall:		0.7272727272727273	Weighted by length:	0.9480249478877621
# Detailed event results:
# 	Actual events:
# 		deletions:			3	27.27% of actual events
# 		merged:				3	27.27% of actual events
# 		fragmented:			0	0.00% of actual events
# 		frag. and merged:	0	0.00% of actual events
# 		correct:			5	45.45% of actual events
# 	Detected events:
# 		insertions:			0	0.00% of detected events
# 		merging:			1	16.67% of detected events
# 		fragmenting:		0	0.00% of detected events
# 		frag. and merging:	0	0.00% of detected events
# 		correct:			5	83.33% of detected events
# [1.0, 0.7272727272727273, 1.0, 0.9480249478877621]
# [1.0, 0.7272727272727273, 1.0, 0.9480249478877621]
# (1.0;0.7272727272727273;1.0;0.9480249478877621)
#
# [5, 3, 3, 0, 0, 0, 1, 0, 0, 11, 6]
# [5, 3, 3, 0, 0, 0, 1, 0, 0, 11, 6]
# (5;3;3;0;0;0;1;0;0;11;6)

# %%
real_events
# Out:
#              StartTime             EndTime Activity Duration
# 0  2020-01-01 00:01:05 2020-01-01 00:02:21        1 00:01:16
# 1  2020-01-01 00:02:37 2020-01-01 00:03:07        1 00:00:30
# 2  2020-01-01 00:04:20 2020-01-01 00:05:04        1 00:00:44
# 3  2020-01-01 00:05:24 2020-01-01 00:05:26        1 00:00:02
# 4  2020-01-01 00:06:20 2020-01-01 00:06:33        1 00:00:13
# 5  2020-01-01 00:07:35 2020-01-01 00:07:50        1 00:00:15
# 6  2020-01-01 00:07:55 2020-01-01 00:08:05        1 00:00:10
# 7  2020-01-01 00:08:25 2020-01-01 00:09:15        1 00:00:50
# 8  2020-01-01 00:11:06 2020-01-01 00:13:27        1 00:02:21
# 9  2020-01-01 00:13:34 2020-01-01 00:14:48        1 00:01:14
# 10 2020-01-01 00:15:03 2020-01-01 00:15:29        1 00:00:26

# %%
dataset.activities_map
# Out:
# {0: 'null', 1: 'Act'}

# %% [raw]
# r
